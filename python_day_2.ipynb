# %%
name='suraj'

# %%
name.capitalize()
# Out:
# 'Suraj'

# %%
name.upper()
# Out:
# 'SURAJ'

# %%
name
# Out:
# 'suraj'

# %%
name='ram amol patil'

# %%
name.split()
#split method is use to covert 'str' into 'list'
# Out:
# ['ram', 'amol', 'patil']

# %%
name1='suraj amol kale'

# %%
name1.split()
# Out:
# ['suraj', 'amol', 'kale']

# %%
#join 
# use to convert 'list' into 'str'.

# %%
a=['avi','ram','sam']

# %%
' '.join(a)
# Out:
# 'avi ram sam'

# %%
name='   suraj'

# %%
name
# Out:
# '   suraj'

# %%
name.lstrip()
# if there is a space in str in left side then we use l-strip
# Out:
# 'suraj'

# %%
name1='suraj   '

# %%
name1.rstrip()
# Out:
# 'suraj'

# %%
name2='      suraj         '  
name2
# Out:
# '      suraj         '

# %%
name.strip()
# Out:
# 'suraj'

# %%
name='1234'

# %%
name.isdigit()
# Out:
# True

# %%
name.isalnum()
# Out:
# True

# %%
name.isnumeric()
# Out:
# True

# %%
#input function

# %%
print('find the area of the circle using any number.')
r=int(input('enter the radius : '))
area=3.14*r*r
print('area of the circle is : ',area)
# Out:
# find the area of the circle using any number.
# enter the radius : 5
# area of the circle is :  78.5

# %%
#str formatting
# means inserting values (variables, no's, exprisions) into a string in a readable and meaning full way.

# %%
print(name1='suraj')
# Out:
# my name is suraj
# my age is 30

# %%
#we use formating to combine text and variables

# %%
#types of formatting

# %%
#1: old style formatting(denetod by %)
#2. string.format() method
#3. f-string formatting
#4. templete string formatting

# %%
name='suraj'
age=30
print('%s and %d'%(name,age))
print('my name is %s and my age is %d'%(name,age))
#%s = str and %d = digit
# Out:
# suraj and 30
# my name is suraj and my age is 30

# %%
name='suraj'
age=25
print(f"my name is {name} and my age is {age}")
# Out:
# my name is suraj and my age is 25

# %%
name='elon musk'
company='tesla'

# %%
print('%s and %s'%(name,company))
print('%s is owner of %s'%(name,company))
# Out:
# elon musk and tesla
# elon musk is owner of tesla

# %%
a=f'the founder of {company} is {name}'

# %%
a
# Out:
# 'the founder of tesla is elon musk'

# %%
"name"
# Out:
# 'name'
