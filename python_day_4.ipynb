# %%
# Math module

# %%
import math as m

# %%
m.sqrt(25)
# Out:
# 5.0

# %%
m.remainder(6,3)
# Out:
# 0.0

# %%
m.factorial(3)
# Out:
# 6

# %%
m.log(1)
# Out:
# 0.0

# %%
m.ceil(4.1)
# Out:
# 5

# %%
m.floor(4.8)
# Out:
# 4

# %%
m.sin(0)
# Out:
# 0.0

# %%
m.sin(90)
# Out:
# 0.8939966636005579

# %%
m.cos(0)
# Out:
# 1.0

# %%
m.tan(0)
# Out:
# 0.0
