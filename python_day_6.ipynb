# %%
'''disision making and looping (are essiential constructs in python that allow you to control the flow of your program and 
 perform reptitive tasks'''
# Out:
# 'disision making and looping (are essiential constructs in python that allow you to control the flow of your program and \n perform reptitive tasks'

# %%
#desision making means choosing one action based on a condition

# %%
#if, else, elif

# %%
#if 
#syntax : 
      #  if condition
      # statment

num=4
if num>2:
    print('+ve')
    
#if is used only for one condition
# Out:
# +ve

# %%
#if else
#syntax 
    #if condition 
    #statment
    #else
    #statment
    
num=3
if num>0:
    print('positive')
else:
    print('negative')
# Out:
# positive

# %%
num=12
if num % 2== 0 :
    print(num,'is even')
else:
    print(num,'is odd')
# Out:
# 12 is even

# %%
name=input('enter your name :')
age=int(input('enter your age :'))
if age>=18:
    print(name,' ki age ',age,' hai to vo adult hai.')
else:
    print(name,' ki age ',age,' hai to vo minnor hai.')
# Out:
# enter your name :amit
# enter your age :21
# amit  ki age  21  hai to vo adult hai.

# %%
a=input('enter the letter :')
if a.isupper():
    print('true it is upper')
else:
    print('false it is not upper')
# Out:
# enter the letter :a
# false it is not upper

# %%
#elif ladder

# %%
# if condition
# statement
# elif condition
# statement
# elif condition
# statement
# else
# statement

# %%
num=int(input('enter the num : '))
if num>0:
    print('positive')
elif num==0:
    print('given no is zero')
else:
    print('negative')
# Out:
# enter the num : 0
# given no is zero

# %%
num=int(input('enter the num : '))
if num>0:
    print('positive')
elif num==0:
    print('given no is zero')
else:
    print('negative')
# Out:
# enter the num : 5
# positive

# %%
num=int(input('enter the num : '))
if num>0:
    print('positive')
elif num==0:
    print('given no is zero')
else:
    print('negative')
# Out:
# enter the num : -5
# negative

# %%
'''marks get from user , if marks>75 =distinction, mark>60 = first class, marks>50 second class, marks>40 = pass class, marks<40 = fail'''
# Out:
# 'marks get from user , if marks>75 =distinction, mark>60 = first class, marks>50 second class, marks>40 = pass class, marks<40 = fail'
