# %%
# comment can write using #.
#variable

# %%
num1=12
type(num1)
# Out:
# int

# %%
num2=12.5
type(num2)
# Out:
# float

# %%
#container data types
#which contains multiple values
#ex: list, tuple, set, dict, range, array, srting.

# %%
#nan-container data types
#which not-contains multiple values
#int, float, complex, boolean type.

# %%
num1=5+3j

# %%
type(num1)
# contain real and imaginary part
# Out:
# complex

# %%
name='amol'

# %%
type(name)
# Out:
# str

# %%
x=None
type(x)
# Out:
# NoneType

# %%
y=True
x=False
type(y)
type(x)
# Out:
# bool

# %%
#list[]

# %%
list1=[2,6,5,9,3]
type(list1)
# Out:
# list

# %%
#tuple()
tup1=(4,6,7,5)
type(tup1)
# Out:
# tuple

# %%
#set{}
a={3,6,8,5,2}
type(a)
# Out:
# set

# %%
#dictionary{:}
dict1={"name":"amol","marks":"100"}
type(dict1)
# Out:
# dict

# %%
#typecasting
#conversion of one data-type into another data-type
#means if a data is in int and we need to convert its type to float then we use [typecasting]

# %%
a=12

# %%
float(a)
# Out:
# 12.0

# %%
complex(a)
# Out:
# (12+0j)

# %%
a='amol'
b=23

# %%
a+str(b)
# Out:
# 'amol23'

# %%
s="shrinath"
d=992004

# %%
type(d)
# Out:
# int

# %%
s+str(d)
# Out:
# 'shrinath992004'

# %%
a=[4,7,8,5,3]

# %%
tuple(a)
# Out:
# (4, 7, 8, 5, 3)

# %%
#string
#set of charcters or collection of charcters
#it is container data type

# %%
#empty string

# %%
'amol'
# Out:
# 'amol'

# %%
type('amol')
# Out:
# str

# %%
b=56

# %%
str(b)
# Out:
# '56'

# %%
#indexing

# %%
# each charcter in string has its own position
# we use to acces a given val
# string supports indixing , there fore it is called as sequence datatype
# python supports +ve,-ve val.

# %%
name='suraj'

# %%
name[-1]
# Out:
# 'j'

# %%
name[2]
# Out:
# 'r'

# %%
#slicing
# to get a some part of string
#start,end,step

# %%
name='suraj'
name[0:5:2]
#here 0 is starting point and 5 is ending
# Out:
# 'srj'

# %%
name[::-1]
# Out:
# 'jarus'

# %%
name[::-2]
# Out:
# 'jrs'

# %%
# functions

# %%
name='suraj'

# %%
type(name)
# Out:
# str

# %%
len(name)
# Out:
# 5

# %%
id(name)
#give memory refrence.
# Out:
# 2179867887536

# %%
min(name)
# Out:
# 'a'

# %%
max(name)
# Out:
# 'u'

# %%
#methods

# %%
name='suraj'

# %%
name.upper()
# Out:
# 'SURAJ'

# %%
name.lower()
# Out:
# 'suraj'

# %%
name.startswith('s')
# Out:
# True

# %%
name.startswith('a')
# Out:
# False

# %%
name.endswith('s')
# Out:
# False

# %%
name.endswith('j')
# Out:
# True

# %%
name.title()
# Out:
# 'Suraj'

# %%
name.count("s")
# Out:
# 1

# %%
name.capitalize()
# Out:
# 'Suraj'

# %%
name.index('j')
# Out:
# 4

# %%
name.replace('s','t')
# Out:
# 'turaj'

# %%
name.isupper()
# Out:
# False

# %%
#if there 'is' in front of any method then it is used ot check that it is in that formate or not.

# %%
name.islower()
# Out:
# True

# %%
name='avi raj sam'

# %%
list(name)
# Out:
# ['a', 'v', 'i', ' ', 'r', 'a', 'j', ' ', 's', 'a', 'm']

# %%
name=['ram','pratik','amol']

# %%
str(name)
# Out:
# "['ram', 'pratik', 'amol']"

# %%
' '.join(name)
#join is meathod is use to convert 'list' into 'string'.
# Out:
# 'ram pratik amol'

# %%
_.join(name)
# Out:
# 'ramram pratik amolpratikram pratik amolamol'

# %%
#input function
# it takes a input form us

# %%
a=input("enter the name : ")
# Out:
# enter the name : aniket

# %%
name=input(" my name is ")
# Out:
#  my name is aniket

# %%
b=int(input("enter the contact no. :"))
# Out:
# enter the contact no. :1236547890

# %%
num1=12
num2=13
result=num1+num2

# %%
result
# Out:
# 25

# %%
b=int(input('enter the base of trangle = '))
c=int(input('enter the height of trangle = '))
area=0.5*b*c
print('area of trangle is :',area)
# Out:
# enter the base of trangle = 3
# enter the height of trangle = 4
# area of trangle is : 6.0

# %%
r=int(input('enter the radius of the circle = '))
area=3.14*r*r
print('the area of the circle is :',area)
# Out:
# enter the radius of the circle = 6
# the area of the circle is : 113.03999999999999

# %%
r=int(input('enter the radius of the sphere = '))
area=4*3.14*r*r
print('the area of the sphere is :',area)
# Out:
# enter the radius of the sphere = 5
# the area of the sphere is : 314.0

# %%
name=input('enter your name : ')
print('your name is : ',name)
# Out:
# enter your name : aniket
# your name is :  aniket
